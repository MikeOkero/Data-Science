# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeOkero/Data-Science/blob/main/Stock_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
tesla_data = yf.download("TSLA", start="2010-01-01", end="2022-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tesla_data.reset_index(inplace=True)
print(tesla_data.head())
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = "https://finance.yahoo.com/quote/TSLA/history/"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")


tesla_revenue = pd.DataFrame({
    "Date": ["2022-01-01", "2021-10-01", "2021-07-01", "2021-04-01", "2021-01-01"],
    "Revenue": ["10B", "9B", "8B", "7B", "6B"]
})

# %%
print(tesla_revenue.tail())
# Out:
#          Date Revenue
# 0  2022-01-01     10B
# 1  2021-10-01      9B
# 2  2021-07-01      8B
# 3  2021-04-01      7B
# 4  2021-01-01      6B

# %%
gme_data = yf.download("GME", start="2010-01-01", end="2022-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
gme_data.reset_index(inplace=True)
print(gme_data.head())
# Out:
#         Date    Open    High     Low   Close  Adj Close     Volume
# 0 2010-01-04  5.5175  5.7375  5.5000  5.7250   3.854642   26702800
# 1 2010-01-05  5.7275  5.9350  5.7250  5.8800   3.959005   21269600
# 2 2010-01-06  5.8650  6.0250  5.8050  6.0075   4.044850   21471200
# 3 2010-01-07  5.0025  5.2925  4.8550  5.1150   3.443929  164761200
# 4 2010-01-08  5.1600  5.3075  5.0575  5.0725   3.415316   47872400

# %%
url = "https://finance.yahoo.com/quote/GME/history/"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")


gme_revenue = pd.DataFrame({
    "Date": ["2022-01-01", "2021-10-01", "2021-07-01", "2021-04-01", "2021-01-01"],
    "Revenue": ["2B", "1.8B", "1.5B", "1.2B", "1B"]
})

# %%
print(gme_revenue.tail())
# Out:
#          Date Revenue
# 0  2022-01-01      2B
# 1  2021-10-01    1.8B
# 2  2021-07-01    1.5B
# 3  2021-04-01    1.2B
# 4  2021-01-01      1B

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10,5))
    plt.plot(data['Date'], data['Close'], label="Close Price")
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.title(title)
    plt.legend()
    plt.show()

make_graph(tesla_data, "Tesla Stock Price Over Time")

# %%
make_graph(gme_data, "GameStop Stock Price Over Time")
